# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(X):
    X_max = np.max(X, axis=-1, keepdims=True)
    X_exp = np.exp(X - X_max)
    X_sum = np.sum(X_exp, axis=-1, keepdims=True)
    return X_exp / X_sum

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
import numpy as np

def relu(batch, stochastic=False):
    activations = np.maximum(batch, 0)
    return activations + (sigmoid(batch) if stochastic else 0)

def relu_derivative(batch):
    return (batch > 0).astype(int)

# %%
def limit_weights(weights, limit):
    norms = np.linalg.norm(weights, axis=0)  
    scale = np.maximum(norms, 1)
    return weights / scale

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M;
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].hidden_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].visible_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

    def step(self, grad):
        
        self.M = self.M * self.momentum + grad
        self.W -= self.M * self.learning_rate

        if self.weight_limit > 0.0:
            self.W[:-1, :] = limit_weights(self.W[:-1, :], self.weight_limit)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        #print(visible.shape, layer.W.shape)
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            prev_layer.deltas = layer.deltas @ layer.W.T[:,:-1] * prev_layer.d_activations
        else:
            visible = batch
        
        grad = visible.T @ layer.deltas / observations_count

        layer.step(grad)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        #raise Exception("Delta in the sofmax layer is unimplemented!")
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for l_mlp, l_dbn in zip(mlp, dbn):
        l_mlp.W = np.copy(l_dbn.W[:, :-1])

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.27s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.30s, accuracy: 26.77
# Epoch 3:	########################################	elapsed: 0.26s, accuracy: 61.57
# Epoch 4:	########################################	elapsed: 0.26s, accuracy: 69.53
# Epoch 5:	########################################	elapsed: 0.31s, accuracy: 76.74
# Epoch 6:	########################################	elapsed: 0.29s, accuracy: 87.71
# Epoch 7:	########################################	elapsed: 0.25s, accuracy: 90.73
# Epoch 8:	########################################	elapsed: 0.24s, accuracy: 91.05
# Epoch 9:	########################################	elapsed: 0.25s, accuracy: 92.96
# Epoch 10:	########################################	elapsed: 0.24s, accuracy: 93.33
# Epoch 11:	########################################	elapsed: 0.24s, accuracy: 93.84
# Epoch 12:	########################################	elapsed: 0.23s, accuracy: 94.01
# Epoch 13:	########################################	elapsed: 0.25s, accuracy: 94.02
# Epoch 14:	########################################	elapsed: 0.23s, accuracy: 94.54
# Epoch 15:	########################################	elapsed: 0.26s, accuracy: 94.69
# Epoch 16:	########################################	elapsed: 0.26s, accuracy: 94.38
# Epoch 17:	########################################	elapsed: 0.26s, accuracy: 94.40
# Epoch 18:	########################################	elapsed: 0.26s, accuracy: 93.97
# Epoch 19:	########################################	elapsed: 0.24s, accuracy: 93.48
# Epoch 20:	########################################	elapsed: 0.23s, accuracy: 92.90
# Epoch 21:	########################################	elapsed: 0.23s, accuracy: 93.41
# Epoch 22:	########################################	elapsed: 0.27s, accuracy: 94.51
# Epoch 23:	########################################	elapsed: 0.26s, accuracy: 94.74
# Epoch 24:	########################################	elapsed: 0.25s, accuracy: 95.29
# Epoch 25:	########################################	elapsed: 0.24s, accuracy: 95.68
# Epoch 26:	########################################	elapsed: 0.25s, accuracy: 95.35
# Epoch 21:	########################################	elapsed: 0.25s, reconstruction error: 10.47
# Epoch 22:	########################################	elapsed: 0.26s, reconstruction error: 10.30
# Epoch 23:	########################################	elapsed: 0.26s, reconstruction error: 10.32
# Epoch 24:	########################################	elapsed: 0.25s, reconstruction error: 10.19
# Epoch 25:	########################################	elapsed: 0.25s, reconstruction error: 10.16
# Epoch 26:	########################################	elapsed: 0.23s, reconstruction error: 10.17
# Epoch 27:	########################################	elapsed: 0.24s, reconstruction error: 10.07
# Epoch 28:	########################################	elapsed: 0.26s, reconstruction error: 10.09
# Epoch 29:	########################################	elapsed: 0.24s, reconstruction error: 10.17
# Epoch 30:	########################################	elapsed: 0.25s, reconstruction error: 10.06
# Epoch 31:	########################################	elapsed: 0.26s, reconstruction error: 10.06
# Epoch 32:	########################################	elapsed: 0.26s, reconstruction error: 10.07
# Epoch 33:	########################################	elapsed: 0.26s, reconstruction error: 9.97
# Epoch 34:	########################################	elapsed: 0.27s, reconstruction error: 9.95
# Epoch 35:	########################################	elapsed: 0.26s, reconstruction error: 10.03
# Epoch 36:	########################################	elapsed: 0.29s, reconstruction error: 10.02
# Epoch 37:	########################################	elapsed: 0.28s, reconstruction error: 9.93
# Epoch 38:	########################################	elapsed: 0.29s, reconstruction error: 9.88
# Epoch 39:	########################################	elapsed: 0.28s, reconstruction error: 9.91
# Epoch 40:	########################################	elapsed: 0.29s, reconstruction error: 9.88
# Epoch 41:	########################################	elapsed: 0.29s, reconstruction error: 9.82
# Epoch 42:	########################################	elapsed: 0.29s, reconstruction error: 9.88
# Epoch 43:	########################################	elapsed: 0.30s, reconstruction error: 9.94
# Epoch 44:	########################################	elapsed: 0.29s, reconstruction error: 9.86
# Epoch 45:	########################################	elapsed: 0.25s, reconstruction error: 9.93
# Epoch 46:	########################################	elapsed: 0.24s, reconstruction error: 9.85
# Epoch 47:	########################################	elapsed: 0.27s, reconstruction error: 9.83
# Epoch 48:	########################################	elapsed: 0.28s, reconstruction error: 9.81
# Epoch 49:	########################################	elapsed: 0.29s, reconstruction error: 9.87
# Epoch 50:	########################################	elapsed: 0.30s, reconstruction error: 9.81
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.11s, reconstruction error: 131.11
# Epoch 2:	########################################	elapsed: 0.11s, reconstruction error: 110.39
# Epoch 3:	########################################	elapsed: 0.11s, reconstruction error: 104.91
# Epoch 4:	########################################	elapsed: 0.09s, reconstruction error: 102.53
# Epoch 5:	########################################	elapsed: 0.09s, reconstruction error: 101.12
# Epoch 6:	########################################	elapsed: 0.10s, reconstruction error: 98.81
# Epoch 7:	########################################	elapsed: 0.10s, reconstruction error: 99.09
# Epoch 8:	########################################	elapsed: 0.10s, reconstruction error: 98.38
# Epoch 9:	########################################	elapsed: 0.10s, reconstruction error: 97.82
# Epoch 10:	########################################	elapsed: 0.09s, reconstruction error: 97.74
# Epoch 11:	########################################	elapsed: 0.10s, reconstruction error: 97.95
# Epoch 12:	########################################	elapsed: 0.09s, reconstruction error: 98.06
# Epoch 13:	########################################	elapsed: 0.10s, reconstruction error: 98.16
# Epoch 14:	########################################	elapsed: 0.09s, reconstruction error: 98.30
# Epoch 15:	########################################	elapsed: 0.09s, reconstruction error: 98.39
# Epoch 16:	########################################	elapsed: 0.09s, reconstruction error: 98.45
# Epoch 17:	########################################	elapsed: 0.09s, reconstruction error: 98.39
# Epoch 18:	########################################	elapsed: 0.09s, reconstruction error: 98.27
# Epoch 19:	########################################	elapsed: 0.10s, reconstruction error: 98.15
# Epoch 20:	########################################	elapsed: 0.09s, reconstruction error: 98.02
# Epoch 21:	########################################	elapsed: 0.11s, reconstruction error: 97.92
# Epoch 22:	########################################	elapsed: 0.10s, reconstruction error: 97.77
# Epoch 23:	########################################	elapsed: 0.10s, reconstruction error: 97.59
# Epoch 24:	########################################	elapsed: 0.10s, reconstruction error: 97.44
# Epoch 25:	########################################	elapsed: 0.09s, reconstruction error: 97.30
# Epoch 26:	########################################	elapsed: 0.09s, reconstruction error: 97.16
# Epoch 27:	########################################	elapsed: 0.09s, reconstruction error: 97.07
# Epoch 28:	########################################	elapsed: 0.09s, reconstruction error: 96.99
# Epoch 29:	########################################	elapsed: 0.09s, reconstruction error: 96.87
# Epoch 30:	########################################	elapsed: 0.10s, reconstruction error: 96.74
# Epoch 31:	########################################	elapsed: 0.10s, reconstruction error: 96.67
# Epoch 32:	########################################	elapsed: 0.12s, reconstruction error: 96.61
# Epoch 33:	########################################	elapsed: 0.10s, reconstruction error: 96.54
# Epoch 34:	########################################	elapsed: 0.10s, reconstruction error: 96.38
# Epoch 35:	########################################	elapsed: 0.11s, reconstruction error: 96.19
# Epoch 36:	########################################	elapsed: 0.11s, reconstruction error: 95.99
# Epoch 37:	########################################	elapsed: 0.11s, reconstruction error: 95.79
# Epoch 38:	########################################	elapsed: 0.11s, reconstruction error: 95.67
# Epoch 39:	########################################	elapsed: 0.11s, reconstruction error: 95.60
# Epoch 40:	########################################	elapsed: 0.10s, reconstruction error: 95.54
# Epoch 41:	########################################	elapsed: 0.12s, reconstruction error: 95.46
# Epoch 42:	########################################	elapsed: 0.11s, reconstruction error: 95.37
# Epoch 43:	########################################	elapsed: 0.09s, reconstruction error: 95.27
# Epoch 44:	########################################	elapsed: 0.09s, reconstruction error: 95.20
# Epoch 45:	########################################	elapsed: 0.10s, reconstruction error: 95.13
# Epoch 46:	########################################	elapsed: 0.09s, reconstruction error: 95.12
# Epoch 47:	########################################	elapsed: 0.09s, reconstruction error: 95.14
# Epoch 48:	########################################	elapsed: 0.09s, reconstruction error: 95.16
# Epoch 49:	########################################	elapsed: 0.09s, reconstruction error: 95.15
# Epoch 50:	########################################	elapsed: 0.09s, reconstruction error: 95.13
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.27s, accuracy: 93.28
# Epoch 2:	########################################	elapsed: 0.28s, accuracy: 94.00
# Epoch 3:	########################################	elapsed: 0.27s, accuracy: 94.34
# Epoch 4:	########################################	elapsed: 0.29s, accuracy: 94.36
# Epoch 5:	########################################	elapsed: 0.31s, accuracy: 93.90
# Epoch 6:	########################################	elapsed: 0.29s, accuracy: 94.12
# Epoch 7:	########################################	elapsed: 0.28s, accuracy: 95.08
# Epoch 8:	########################################	elapsed: 0.27s, accuracy: 95.39
# Epoch 9:	########################################	elapsed: 0.28s, accuracy: 95.88
IDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

deep_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0),
    Rbm(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 0.44s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 0.44s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 0.47s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 0.40s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 0.41s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 0.40s, accuracy: 41.71
# Epoch 7:	########################################	elapsed: 0.41s, accuracy: 80.79
# Epoch 8:	########################################	elapsed: 0.43s, accuracy: 88.27
# Epoch 9:	########################################	elapsed: 0.41s, accuracy: 90.64
# Epoch 10:	########################################	elapsed: 0.46s, accuracy: 91.17
# Epoch 11:	########################################	elapsed: 0.45s, accuracy: 93.10
# Epoch 12:	########################################	elapsed: 0.50s, accuracy: 92.81
# Epoch 13:	########################################	elapsed: 0.47s, accuracy: 93.66
# Epoch 14:	########################################	elapsed: 0.45s, accuracy: 93.18
# Epoch 15:	########################################	elapsed: 0.41s, accuracy: 93.27
# Epoch 16:	########################################	elapsed: 0.41s, accuracy: 94.92
# Epoch 17:	########################################	elapsed: 0.50s, accuracy: 95.05
# Epoch 18:	########################################	elapsed: 0.42s, accuracy: 93.62
# Epoch 19:	########################################	elapsed: 0.44s, accuracy: 93.70
# Epoch 20:	########################################	elapsed: 0.44s, accuracy: 95.61
# Epoch 21:	########################################	elapsed: 0.40s, accuracy: 95.60
# Epoch 22:	########################################	elapsed: 0.46s, accuracy: 93.08
# Epoch 23:	########################################	elapsed: 0.51s, accuracy: 95.31
# Epoch 24:	########################################	elapsed: 0.45s, accuracy: 94.64
# Epoch 25:	########################################	elapsed: 0.49s, accuracy: 94.09
# Epoch 26:	########################################	elapsed: 0.40s, accuracy: 94.55
# Epoch 27:	########################################	elapsed: 0.39s, accuracy: 94.63
# Epoch 28:	########################################	elapsed: 0.49s, accuracy: 94.98
# Epoch 29:	########################################	elapsed: 0.46s, accuracy: 95.28
# Epoch 30:	########################################	elapsed: 0.43s, accuracy: 94.93
# Epoch 31:	########################################	elapsed: 0.44s, accuracy: 96.05
# Epoch 32:	########################################	elapsed: 0.41s, accuracy: 95.59
# Epoch 33:	########################################	elapsed: 0.40s, accuracy: 95.83
# Epoch 34:	########################################	elapsed: 0.45s, accuracy: 96.34
# Epoch 35:	########################################	elapsed: 0.47s, accuracy: 96.16
# Epoch 36:	########################################	elapsed: 0.42s, accuracy: 95.46
# Epoch 37:	########################################	elapsed: 0.48s, accuracy: 96.16
# Epoch 38:	########################################	elapsed: 0.42s, accuracy: 96.36
# Epoch 39:	########################################	elapsed: 0.44s, accuracy: 96.46
# Epoch 40:	########################################	elapsed: 0.43s, accuracy: 96.70
# Epoch 41:	########################################	elapsed: 0.40s, accuracy: 96.78
# Epoch 42:	########################################	elapsed: 0.41s, accuracy: 96.76
# Epoch 43:	########################################	elapsed: 0.42s, accuracy: 96.79
# Epoch 44:	########################################	elapsed: 0.40s, accuracy: 96.80
# Epoch 45:	########################################	elapsed: 0.39s, accuracy: 96.80
# Epoch 46:	########################################	elapsed: 0.40s, accuracy: 96.81
# Epoch 47:	########################################	elapsed: 0.42s, accuracy: 96.88
# Epoch 48:	########################################	elapsed: 0.39s, accuracy: 96.84
# Epoch 49:	########################################	elapsed: 0.48s, accuracy: 96.84
# Epoch 50:	########################################	elapsed: 0.49s, accuracy: 96.85
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 1.00
# 	layer 2: 1.00
# 	layer 3: 1.00
# 	layer 4: 1.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.23s, reconstruction error: 71.46
# Epoch 2:	########################################	elapsed: 0.24s, reconstruction error: 52.47
# Epoch 3:	########################################	elapsed: 0.22s, reconstruction error: 40.43
# Epoch 4:	########################################	elapsed: 0.24s, reconstruction error: 34.70
# Epoch 5:	########################################	elapsed: 0.22s, reconstruction error: 31.25
# Epoch 6:	########################################	elapsed: 0.24s, reconstruction error: 23.83
# Epoch 7:	########################################	elapsed: 0.23s, reconstruction error: 20.10
# Epoch 8:	########################################	elapsed: 0.24s, reconstruction error: 17.91
# Epoch 9:	########################################	elapsed: 0.25s, reconstruction error: 16.25
# Epoch 10:	########################################	elapsed: 0.23s, reconstruction error: 15.09
# Epoch 11:	########################################	elapsed: 0.23s, reconstruction error: 14.20
# Epoch 12:	########################################	elapsed: 0.25s, reconstruction error: 13.59
# Epoch 13:	########################################	elapsed: 0.23s, reconstruction error: 12.92
# Epoch 14:	########################################	elapsed: 0.22s, reconstruction error: 12.45
# Epoch 15:	########################################	elapsed: 0.23s, reconstruction error: 12.08
# Epoch 16:	########################################	elapsed: 0.24s, reconstruction error: 11.72
# Epoch 17:	########################################	elapsed: 0.24s, reconstruction error: 11.39
# Epoch 18:	########################################	elapsed: 0.23s, reconstruction error: 11.12
# Epoch 19:	########################################	elapsed: 0.23s, reconstruction error: 11.02
# Epoch 20:	########################################	elapsed: 0.24s, reconstruction error: 10.82
# Epoch 21:	########################################	elapsed: 0.24s, reconstruction error: 10.69
# Epoch 22:	########################################	elapsed: 0.24s, reconstruction error: 10.57
# Epoch 23:	########################################	elapsed: 0.24s, reconstruction error: 10.43
# Epoch 24:	########################################	elapsed: 0.25s, reconstruction error: 10.42
# Epoch 25:	########################################	elapsed: 0.26s, reconstruction error: 10.29
# Epoch 26:	########################################	elapsed: 0.26s, reconstruction error: 10.32
# Epoch 27:	########################################	elapsed: 0.26s, reconstruction error: 10.36
# Epoch 28:	########################################	elapsed: 0.26s, reconstruction error: 10.26
# Epoch 29:	########################################	elapsed: 0.24s, reconstruction error: 10.37
# Epoch 30:	########################################	elapsed: 0.23s, reconstruction error: 10.25
# Epoch 31:	########################################	elapsed: 0.24s, reconstruction error: 10.23
# Epoch 32:	########################################	elapsed: 0.24s, reconstruction error: 10.20
# Epoch 33:	########################################	elapsed: 0.24s, reconstruction error: 10.29
# Epoch 34:	########################################	elapsed: 0.24s, reconstruction error: 10.30
# Epoch 35:	########################################	elapsed: 0.23s, reconstruction error: 10.29
# Epoch 36:	########################################	elapsed: 0.23s, reconstruction error: 10.31
# Epoch 37:	########################################	elapsed: 0.25s, reconstruction error: 10.20
# Epoch 38:	########################################	elapsed: 0.24s, reconstruction error: 10.26
# Epoch 39:	########################################	elapsed: 0.24s, reconstruction error: 10.28
# Epoch 40:	########################################	elapsed: 0.28s, reconstruction error: 10.22
# Epoch 41:	########################################	elapsed: 0.26s, reconstruction error: 10.25
# Epoch 42:	########################################	elapsed: 0.26s, reconstruction error: 10.25
# Epoch 43:	########################################	elapsed: 0.25s, reconstruction error: 10.18
# Epoch 44:	########################################	elapsed: 0.27s, reconstruction error: 10.23
# Epoch 45:	########################################	elapsed: 0.28s, reconstruction error: 10.12
# Epoch 46:	########################################	elapsed: 0.27s, reconstruction error: 10.23
# Epoch 47:	########################################	elapsed: 0.26s, reconstruction error: 10.20
# Epoch 48:	########################################	elapsed: 0.26s, reconstruction error: 10.14
# Epoch 49:	########################################	elapsed: 0.24s, reconstruction error: 10.16
# Epoch 50:	########################################	elapsed: 0.24s, reconstruction error: 10.22
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.08s, reconstruction error: 132.80
# Epoch 2:	########################################	elapsed: 0.09s, reconstruction error: 111.55
# Epoch 3:	########################################	elapsed: 0.11s, reconstruction error: 106.55
# Epoch 4:	########################################	elapsed: 0.10s, reconstruction error: 104.58
# Epoch 5:	########################################	elapsed: 0.08s, reconstruction error: 103.72
# Epoch 6:	########################################	elapsed: 0.09s, reconstruction error: 104.91
# Epoch 7:	########################################	elapsed: 0.11s, reconstruction error: 103.32
# Epoch 8:	########################################	elapsed: 0.10s, reconstruction error: 102.52
# Epoch 9:	########################################	elapsed: 0.10s, reconstruction error: 102.26
# Epoch 10:	########################################	elapsed: 0.10s, reconstruction error: 102.61
# Epoch 11:	########################################	elapsed: 0.10s, reconstruction error: 102.81
# Epoch 12:	########################################	elapsed: 0.11s, reconstruction error: 102.92
# Epoch 13:	########################################	elapsed: 0.10s, reconstruction error: 102.90
# Epoch 14:	########################################	elapsed: 0.11s, reconstruction error: 102.88
# Epoch 15:	########################################	elapsed: 0.10s, reconstruction error: 102.85
# Epoch 16:	########################################	elapsed: 0.09s, reconstruction error: 102.79
# Epoch 17:	########################################	elapsed: 0.09s, reconstruction error: 102.65
# Epoch 18:	########################################	elapsed: 0.09s, reconstruction error: 102.62
# Epoch 19:	########################################	elapsed: 0.10s, reconstruction error: 102.68
# Epoch 20:	########################################	elapsed: 0.09s, reconstruction error: 102.67
# Epoch 21:	########################################	elapsed: 0.09s, reconstruction error: 102.63
# Epoch 22:	########################################	elapsed: 0.09s, reconstruction error: 102.70
# Epoch 23:	########################################	elapsed: 0.09s, reconstruction error: 102.73
# Epoch 24:	########################################	elapsed: 0.10s, reconstruction error: 102.73
# Epoch 25:	########################################	elapsed: 0.09s, reconstruction error: 102.67
# Epoch 26:	########################################	elapsed: 0.08s, reconstruction error: 102.57
# Epoch 27:	########################################	elapsed: 0.08s, reconstruction error: 102.51
# Epoch 28:	########################################	elapsed: 0.09s, reconstruction error: 102.45
# Epoch 29:	########################################	elapsed: 0.09s, reconstruction error: 102.31
# Epoch 30:	########################################	elapsed: 0.08s, reconstruction error: 102.15
# Epoch 31:	########################################	elapsed: 0.09s, reconstruction error: 102.06
# Epoch 32:	########################################	elapsed: 0.10s, reconstruction error: 101.95
# Epoch 33:	########################################	elapsed: 0.09s, reconstruction error: 101.80
# Epoch 34:	########################################	elapsed: 0.09s, reconstruction error: 101.66
# Epoch 35:	########################################	elapsed: 0.09s, reconstruction error: 101.52
# Epoch 36:	########################################	elapsed: 0.09s, reconstruction error: 101.33
# Epoch 37:	########################################	elapsed: 0.09s, reconstruction error: 101.15
# Epoch 38:	########################################	elapsed: 0.10s, reconstruction error: 100.99
# Epoch 39:	########################################	elapsed: 0.10s, reconstruction error: 100.84
# Epoch 40:	########################################	elapsed: 0.09s, reconstruction error: 100.72
# Epoch 41:	########################################	elapsed: 0.08s, reconstruction error: 100.57
# Epoch 42:	########################################	elapsed: 0.09s, reconstruction error: 100.41
# Epoch 43:	########################################	elapsed: 0.08s, reconstruction error: 100.25
# Epoch 44:	########################################	elapsed: 0.08s, reconstruction error: 100.11
# Epoch 45:	########################################	elapsed: 0.08s, reconstruction error: 99.98
# Epoch 46:	########################################	elapsed: 0.09s, reconstruction error: 99.87
# Epoch 47:	########################################	elapsed: 0.10s, reconstruction error: 99.79
# Epoch 48:	########################################	elapsed: 0.09s, reconstruction error: 99.71
# Epoch 49:	########################################	elapsed: 0.09s, reconstruction error: 99.63
# Epoch 50:	########################################	elapsed: 0.09s, reconstruction error: 99.55
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.16s, reconstruction error: 91.06
# Epoch 2:	########################################	elapsed: 0.17s, reconstruction error: 66.86
# Epoch 3:	########################################	elapsed: 0.14s, reconstruction error: 58.35
# Epoch 4:	########################################	elapsed: 0.15s, reconstruction error: 55.21
# Epoch 5:	########################################	elapsed: 0.15s, reconstruction error: 53.77
# Epoch 6:	########################################	elapsed: 0.14s, reconstruction error: 50.63
# Epoch 7:	########################################	elapsed: 0.16s, reconstruction error: 50.13
# Epoch 8:	########################################	elapsed: 0.15s, reconstruction error: 49.98
# Epoch 9:	########################################	elapsed: 0.14s, reconstruction error: 50.04
# Epoch 10:	########################################	elapsed: 0.14s, reconstruction error: 50.14
# Epoch 11:	########################################	elapsed: 0.14s, reconstruction error: 50.12
# Epoch 12:	########################################	elapsed: 0.15s, reconstruction error: 49.89
# Epoch 13:	########################################	elapsed: 0.15s, reconstruction error: 49.53
# Epoch 14:	########################################	elapsed: 0.15s, reconstruction error: 49.32
# Epoch 15:	########################################	elapsed: 0.15s, reconstruction error: 49.25
# Epoch 16:	########################################	elapsed: 0.15s, reconstruction error: 49.23
# Epoch 17:	########################################	elapsed: 0.15s, reconstruction error: 49.20
# Epoch 18:	########################################	elapsed: 0.16s, reconstruction error: 49.13
# Epoch 19:	########################################	elapsed: 0.15s, reconstruction error: 49.01
# Epoch 20:	########################################	elapsed: 0.16s, reconstruction error: 48.85
# Epoch 21:	########################################	elapsed: 0.18s, reconstruction error: 48.65
# Epoch 22:	########################################	elapsed: 0.15s, reconstruction error: 48.41
# Epoch 23:	########################################	elapsed: 0.14s, reconstruction error: 48.15
# Epoch 24:	########################################	elapsed: 0.15s, reconstruction error: 47.88
# Epoch 25:	########################################	elapsed: 0.14s, reconstruction error: 47.63
# Epoch 26:	########################################	elapsed: 0.15s, reconstruction error: 47.40
# Epoch 27:	########################################	elapsed: 0.16s, reconstruction error: 47.22
# Epoch 28:	########################################	elapsed: 0.15s, reconstruction error: 47.07
# Epoch 29:	########################################	elapsed: 0.14s, reconstruction error: 46.96
# Epoch 30:	########################################	elapsed: 0.16s, reconstruction error: 46.87
# Epoch 31:	########################################	elapsed: 0.15s, reconstruction error: 46.80
# Epoch 32:	########################################	elapsed: 0.15s, reconstruction error: 46.75
# Epoch 33:	########################################	elapsed: 0.16s, reconstruction error: 46.72
# Epoch 34:	########################################	elapsed: 0.15s, reconstruction error: 46.70
# Epoch 35:	########################################	elapsed: 0.15s, reconstruction error: 46.69
# Epoch 36:	########################################	elapsed: 0.16s, reconstruction error: 46.68
# Epoch 37:	########################################	elapsed: 0.16s, reconstruction error: 46.68
# Epoch 38:	########################################	elapsed: 0.16s, reconstruction error: 46.69
# Epoch 39:	########################################	elapsed: 0.16s, reconstruction error: 46.70
# Epoch 40:	########################################	elapsed: 0.16s, reconstruction error: 46.70
# Epoch 41:	########################################	elapsed: 0.16s, reconstruction error: 46.70
# Epoch 42:	########################################	elapsed: 0.15s, reconstruction error: 46.71
# Epoch 43:	########################################	elapsed: 0.17s, reconstruction error: 46.72
# Epoch 44:	########################################	elapsed: 0.17s, reconstruction error: 46.72
# Epoch 45:	########################################	elapsed: 0.17s, reconstruction error: 46.73
# Epoch 46:	########################################	elapsed: 0.16s, reconstruction error: 46.73
# Epoch 47:	########################################	elapsed: 0.16s, reconstruction error: 46.72
# Epoch 48:	########################################	elapsed: 0.16s, reconstruction error: 46.71
# Epoch 49:	########################################	elapsed: 0.15s, reconstruction error: 46.70
# Epoch 50:	########################################	elapsed: 0.15s, reconstruction error: 46.68
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.39s, accuracy: 94.53
# Epoch 2:	########################################	elapsed: 0.40s, accuracy: 94.06
# Epoch 3:	########################################	elapsed: 0.42s, accuracy: 94.03
# Epoch 4:	########################################	elapsed: 0.42s, accuracy: 95.04
# Epoch 5:	########################################	elapsed: 0.41s, accuracy: 95.05
# Epoch 6:	########################################	elapsed: 0.47s, accuracy: 94.02
# Epoch 7:	########################################	elapsed: 0.46s, accuracy: 94.05
# Epoch 8:	########################################	elapsed: 0.58s, accuracy: 94.51
