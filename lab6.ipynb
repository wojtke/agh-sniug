# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(2)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Backpropagation algorithm

# %%
def sigmoid(batch):
    return 1.0 / (1.0 + np.exp(-batch))

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, b_learning_rate,momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.b_learning_rate = b_learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Softmax activation
#
# Implement the softmax activation function. Remember that naive sotmax implementation is numerically unstable: the numerator and the denominator may overflow. Make sure that your implementation has no overflow issues.

# %%
def softmax(X):
    X_max = np.max(X, axis=-1, keepdims=True)
    X_exp = np.exp(X - X_max)
    X_sum = np.sum(X_exp, axis=-1, keepdims=True)
    return X_exp / X_sum

# %% [markdown]
# ### Forward pass
#
# Calculate the total input to the neurons. Then calculate the activations (remember to add *ones* as the last column). Store the result in `layer.activations`.
#
# ##### Computing derivatives of activation function
#
# If `compute_derivatives` is set to `True`, we also need to compute the derivatives of the activation function and store them in `layer.d_activations`. We **do not** need to add *ones column* to the derivatives matrix! *Ones* are only needed in the activations matrix, where they are used to add biases to the total input of neurons in the next hidden layer.

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        #print(visible.shape, layer.W.shape)
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation
#
# Fist, we need to calculate the deltas in `prev_layer`. To calculate them we use:
#  - deltas and weights from `layer`,
#  - derivatives of the activation function from `prev_layer`.
#
# Once *deltas* are calculated, we can use them to compute gradients.

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = layer.deltas @ layer.W.T[:,:-1] * prev_layer.d_activations
        else:
            visible = batch
        
        grad = visible.T @ layer.deltas / observations_count
        
        layer.M = layer.M * layer.momentum + grad #* (1 - layer.momentum)

        layer.W.T[:,:-1] -= layer.M.T[:,:-1] * layer.learning_rate
        layer.W.T[:,-1] -= layer.M.T[:,-1] * layer.b_learning_rate

# %% [markdown]
# ### MLP training
#
# In order to start the back propagation procedure, we need to compute *deltas* in the output layer (that is $\Delta^{\left(y\right)}$). Use network output (from the forward pass) and target labels (stored in `batch_labels`) to calculate the *deltas*. Remember that the output layer is a softmax and that we minimize cross-entropy cost.

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        # Forward pass: compute activatations and derivatives of activations
        y = forward_pass(mlp, batch, True)
        
        #raise Exception("Delta in the sofmax layer is unimplemented!")
        mlp[-1].deltas = y - batch_labels
        
        # Once softmax deltas are set, we may backpropagate errors
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %% [markdown]
# # MNIST digits classification

# %%
def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def run_training(mlp, train_set, train_labels,
                 validation_set, validation_labels,
                 batch_size, epochs_count):
    
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")

        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %%
def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1, :].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
B_LEARNING_RATE = 0.2
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.9

mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, B_LEARNING_RATE, MOMENTUM),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, B_LEARNING_RATE, MOMENTUM),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, B_LEARNING_RATE, MOMENTUM)
]

draw_layer_filters(mlp[0])

run_training(mlp,
             mnist_train_images, mnist_train_labels,
             mnist_test_images, mnist_test_labels,
             BATCH_SIZE, EPOCHS_COUNT)

draw_layer_filters(mlp[0])
# Out:
# Epoch 1:	#####################################################	elapsed: 0.26s, accuracy: 23.96
# Epoch 2:	#####################################################	elapsed: 0.24s, accuracy: 33.12
# Epoch 3:	#####################################################	elapsed: 0.24s, accuracy: 37.08
# Epoch 4:	#####################################################	elapsed: 0.26s, accuracy: 49.29
# Epoch 5:	#####################################################	elapsed: 0.26s, accuracy: 70.95
# Epoch 6:	#####################################################	elapsed: 0.26s, accuracy: 85.45
# Epoch 7:	#####################################################	elapsed: 0.24s, accuracy: 89.00
# Epoch 8:	#####################################################	elapsed: 0.24s, accuracy: 90.21
# Epoch 9:	#####################################################	elapsed: 0.24s, accuracy: 90.82
# Epoch 10:	#####################################################	elapsed: 0.24s, accuracy: 91.49
# Epoch 11:	#####################################################	elapsed: 0.24s, accuracy: 91.94
# Epoch 12:	#####################################################	elapsed: 0.24s, accuracy: 92.31
# Epoch 13:	#####################################################	elapsed: 0.24s, accuracy: 92.63
# Epoch 14:	#####################################################	elapsed: 0.24s, accuracy: 92.92
# Epoch 15:	#####################################################	elapsed: 0.24s, accuracy: 93.27
# Epoch 16:	#####################################################	elapsed: 0.24s, accuracy: 93.57
# Epoch 17:	#####################################################	elapsed: 0.24s, accuracy: 93.88
# Epoch 18:	#####################################################	elapsed: 0.24s, accuracy: 94.04
# Epoch 19:	#####################################################	elapsed: 0.24s, accuracy: 94.26
# Epoch 20:	#####################################################	elapsed: 0.24s, accuracy: 94.55
# Epoch 21:	#####################################################	elapsed: 0.25s, accuracy: 94.77
# Epoch 22:	#####################################################	elapsed: 0.25s, accuracy: 95.00
# Epoch 23:	#####################################################	elapsed: 0.24s, accuracy: 95.21
# Epoch 24:	#####################################################	elapsed: 0.24s, accuracy: 95.35
# Epoch 25:	#####################################################	elapsed: 0.24s, accuracy: 95.57
# Epoch 26:	#####################################################	elapsed: 0.24s, accuracy: 95.61
# Epoch 27:	#####################################################	elapsed: 0.25s, accuracy: 95.59
# Epoch 28:	#####################################################	elapsed: 0.24s, accuracy: 95.64
# Epoch 29:	#####################################################	elapsed: 0.24s, accuracy: 95.73
# Epoch 30:	#####################################################	elapsed: 0.25s, accuracy: 95.89
# Epoch 31:	#####################################################	elapsed: 0.24s, accuracy: 95.75
# Epoch 32:	#####################################################	elapsed: 0.24s, accuracy: 95.81
# Epoch 33:	#####################################################	elapsed: 0.25s, accuracy: 95.86
# Epoch 34:	#####################################################	elapsed: 0.24s, accuracy: 95.97
# Epoch 35:	#####################################################	elapsed: 0.26s, accuracy: 96.09
# Epoch 36:	#####################################################	elapsed: 0.28s, accuracy: 96.10
# Epoch 37:	#####################################################	elapsed: 0.27s, accuracy: 96.14
# Epoch 38:	#####################################################	elapsed: 0.28s, accuracy: 96.21
# Epoch 39:	#####################################################	elapsed: 0.26s, accuracy: 96.20
# Epoch 40:	#####################################################	elapsed: 0.30s, accuracy: 96.05
# Epoch 41:	#####################################################	elapsed: 0.29s, accuracy: 96.13
# Epoch 42:	#####################################################	elapsed: 0.25s, accuracy: 96.34
# Epoch 43:	#####################################################	elapsed: 0.25s, accuracy: 96.35
# Epoch 44:	#####################################################	elapsed: 0.26s, accuracy: 96.43
# Epoch 45:	#####################################################	elapsed: 0.26s, accuracy: 96.51
# Epoch 46:	#####################################################	elapsed: 0.27s, accuracy: 96.57
# Epoch 47:	#####################################################	elapsed: 0.24s, accuracy: 96.58
# Epoch 48:	#####################################################	elapsed: 0.24s, accuracy: 96.58
# Epoch 49:	#####################################################	elapsed: 0.24s, accuracy: 96.65
# Epoch 50:	#####################################################	elapsed: 0.24s, accuracy: 96.68
# Training finished!

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
B_LEARNING_RATE = 0.0
SOFTMAX_LEARNING_RATE = 0.15
MOMENTUM = 0.9

mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, B_LEARNING_RATE, MOMENTUM),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, sigmoid_derivative, LEARNING_RATE, B_LEARNING_RATE, MOMENTUM),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, B_LEARNING_RATE, MOMENTUM)
]

draw_layer_filters(mlp[0])

run_training(mlp,
             mnist_train_images, mnist_train_labels,
             mnist_test_images, mnist_test_labels,
             BATCH_SIZE, EPOCHS_COUNT)

draw_layer_filters(mlp[0])
# Out:
# Epoch 1:	#####################################################	elapsed: 0.24s, accuracy: 11.35
# Epoch 2:	#####################################################	elapsed: 0.23s, accuracy: 29.34
# Epoch 3:	#####################################################	elapsed: 0.25s, accuracy: 34.65
# Epoch 4:	#####################################################	elapsed: 0.24s, accuracy: 51.83
# Epoch 5:	#####################################################	elapsed: 0.24s, accuracy: 74.87
# Epoch 6:	#####################################################	elapsed: 0.24s, accuracy: 85.82
# Epoch 7:	#####################################################	elapsed: 0.24s, accuracy: 89.78
# Epoch 8:	#####################################################	elapsed: 0.25s, accuracy: 91.16
# Epoch 9:	#####################################################	elapsed: 0.24s, accuracy: 91.97
# Epoch 10:	#####################################################	elapsed: 0.24s, accuracy: 92.55
# Epoch 11:	#####################################################	elapsed: 0.24s, accuracy: 93.16
# Epoch 12:	#####################################################	elapsed: 0.24s, accuracy: 93.67
# Epoch 13:	#####################################################	elapsed: 0.24s, accuracy: 93.98
# Epoch 14:	#####################################################	elapsed: 0.24s, accuracy: 94.09
# Epoch 15:	#####################################################	elapsed: 0.24s, accuracy: 94.16
# Epoch 16:	#####################################################	elapsed: 0.25s, accuracy: 94.28
# Epoch 17:	#####################################################	elapsed: 0.24s, accuracy: 94.46
# Epoch 18:	#####################################################	elapsed: 0.24s, accuracy: 94.59
# Epoch 19:	#####################################################	elapsed: 0.26s, accuracy: 94.63
# Epoch 20:	#####################################################	elapsed: 0.24s, accuracy: 94.78
# Epoch 21:	#####################################################	elapsed: 0.26s, accuracy: 94.99
# Epoch 22:	#####################################################	elapsed: 0.24s, accuracy: 95.22
# Epoch 23:	#####################################################	elapsed: 0.25s, accuracy: 95.43
# Epoch 24:	#####################################################	elapsed: 0.24s, accuracy: 95.65
# Epoch 25:	#####################################################	elapsed: 0.24s, accuracy: 95.75
# Epoch 26:	#####################################################	elapsed: 0.24s, accuracy: 95.85
# Epoch 27:	#####################################################	elapsed: 0.24s, accuracy: 95.98
# Epoch 28:	#####################################################	elapsed: 0.26s, accuracy: 96.05
# Epoch 29:	#####################################################	elapsed: 0.26s, accuracy: 96.09
# Epoch 30:	#####################################################	elapsed: 0.25s, accuracy: 96.12
# Epoch 31:	#####################################################	elapsed: 0.24s, accuracy: 96.17
# Epoch 32:	#####################################################	elapsed: 0.27s, accuracy: 96.13
# Epoch 33:	#####################################################	elapsed: 0.25s, accuracy: 96.21
# Epoch 34:	#####################################################	elapsed: 0.25s, accuracy: 96.23
# Epoch 35:	#####################################################	elapsed: 0.24s, accuracy: 96.27
# Epoch 36:	#####################################################	elapsed: 0.24s, accuracy: 96.19
# Epoch 37:	#####################################################	elapsed: 0.24s, accuracy: 95.96
# Epoch 38:	#####################################################	elapsed: 0.24s, accuracy: 95.90
# Epoch 39:	#####################################################	elapsed: 0.24s, accuracy: 95.99
# Epoch 40:	#####################################################	elapsed: 0.24s, accuracy: 96.15
# Epoch 41:	#####################################################	elapsed: 0.24s, accuracy: 96.30
# Epoch 42:	#####################################################	elapsed: 0.24s, accuracy: 96.50
# Epoch 43:	#####################################################	elapsed: 0.25s, accuracy: 96.48
# Epoch 44:	#####################################################	elapsed: 0.25s, accuracy: 96.52
# Epoch 45:	#####################################################	elapsed: 0.25s, accuracy: 96.58
# Epoch 46:	#####################################################	elapsed: 0.26s, accuracy: 96.64
# Epoch 47:	#####################################################	elapsed: 0.25s, accuracy: 96.64
# Epoch 48:	#####################################################	elapsed: 0.24s, accuracy: 96.65
# Epoch 49:	#####################################################	elapsed: 0.24s, accuracy: 96.62
# Epoch 50:	#####################################################	elapsed: 0.24s, accuracy: 96.60
# Training finished!
